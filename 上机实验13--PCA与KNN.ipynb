# %% [markdown]
# ## 任务1：PCA实现

# %% [markdown]
# ### 任务介绍：
# - 请使用Numpy实现PCA，定义为一个函数pca()
# - 函数包含两个参数：dataMat数据矩阵和n_components低维维数，并返回在新空间下的数据矩阵lowdMat和转换矩阵tfMat
# - 现已经读取鸢尾花数据iris.csv得到iris，请利用自定义pca()将数据从四维降到二维空间，得到最终的低维数据矩阵iris2d

# %% [markdown]
# > 待完善代码

# %%
import pandas as pd
import numpy as np
from numpy import linalg as LA

# 读取数据
iris = pd.read_csv('iris.csv', usecols=range(4))

# 定义主成分分析函数
def pca(dataMat, n_components):
    
    # 数据中心化
    meanVals = np.mean(dataMat, axis=0)  # shape(1, 4)
    centered = dataMat - meanVals  # shape(150, 4)
    
    # 计算协方差矩阵，并进行特征值分解
    # 注意，协方差矩阵计算需指定rowvar参数为False，即表明每一列为每一个特征的不同取值
    ## 参考https://blog.csdn.net/m0_68795816/article/details/124575452
    covMat = np.cov(centered, rowvar=False)  # shape(4, 4)
    w, v = LA.eig(covMat)  # 特征值和特征向量    # shape(4,) shape(4, 4)
    
    # 将特征值从大到小排序，并得到对应的索引值序列
    idxMin2Max = np.argsort(w)  # array([3, 2, 1, 0])
    idxMax2Min = idxMin2Max[::-1]  # array([0, 1, 2, 3])
    
    # 根据排序后的索引值序列idxMax2Min提取前n_components个特征向量构成转换矩阵
    # print(idxMax2Min)
    # print(idxMax2Min[:n_components])
    # print(v)
    # print(v[:, idxMax2Min])
    # print(v[:, idxMax2Min][:n_components])
    # print(v[:, idxMax2Min[:n_components]])
    # tfMat = v[:, idxMax2Min[:n_components]]  # 求出来的每一列是特征值, 应该索引前两列值
    # print(v)
    # print(v.T)
    # print(v.T[idxMax2Min])
    # print(v.T[idxMax2Min][:n_components])
    #### 参考https://www.bilibili.com/video/BV1wS4y1f7z1?p=12
    v = v.T  # =============求出来的每一列是特征值, 应该索引前两列值============= #
    v = v[idxMax2Min]  # 这样就可以对行索引排序了
    tfMat = v[:n_components]  # 然后行索引
    # tfMat = tfMat[:n_components]  # n_components×n  shape(2, 4)
    
    # 将原始数据转换到新的低维空间
    lowdMat = np.matmul(dataMat, tfMat.T) # m×n * n×n_components
    
    return lowdMat, tfMat

# 使用自定义pca函数对鸢尾花数据进行降维
irisMat = np.mat(iris)
iris2d, _ = pca(irisMat, 2)

print(iris2d)
# Out:
# [[ 2.82713597 -5.64133105]
#  [ 2.79595248 -5.14516688]
#  [ 2.62152356 -5.17737812]
#  [ 2.7649059  -5.00359942]
#  [ 2.78275012 -5.64864829]
#  [ 3.23144574 -6.06250644]
#  [ 2.69045242 -5.23261922]
#  [ 2.8848611  -5.48512908]
#  [ 2.62338453 -4.7439257 ]
#  [ 2.83749841 -5.20803203]
#  [ 3.00481631 -5.96665874]
#  [ 2.89820038 -5.33624436]
#  [ 2.72390912 -5.08698354]
#  [ 2.28614265 -4.81144382]
#  [ 2.86779988 -6.50091863]
#  [ 3.12747377 -6.65947808]
#  [ 2.88881689 -6.13281341]
#  [ 2.86302037 -5.6338604 ]
#  [ 3.31226514 -6.19396782]
#  [ 2.92399691 -5.83519737]
#  [ 3.2008114  -5.71259155]
#  [ 2.96810819 -5.75475549]
#  [ 2.2954854  -5.4563393 ]
#  [ 3.20821456 -5.42024641]
#  [ 3.15517201 -5.28351414]
#  [ 3.00342587 -5.17566739]
#  [ 3.0422871  -5.45261105]
#  [ 2.94895215 -5.68940829]
#  [ 2.87152183 -5.6340138 ]
#  [ 2.87849519 -5.1246479 ]
#  [ 2.92288105 -5.11733065]
#  [ 3.10126576 -5.73280374]
#  [ 2.86370642 -6.13470636]
#  [ 2.91418362 -6.41474566]
#  [ 2.83749841 -5.20803203]
#  [ 2.64434325 -5.39191683]
#  [ 2.88611463 -5.92152374]
#  [ 2.83749841 -5.20803203]
#  [ 2.52950043 -4.83447368]
#  [ 2.92102007 -5.55078307]
#  [ 2.74120419 -5.58578315]
#  [ 2.65913202 -4.38185836]
#  [ 2.51304665 -4.98041616]
#  [ 3.105829   -5.51064099]
#  [ 3.30251014 -5.75741976]
#  [ 2.79567791 -5.07204225]
#  [ 2.97376973 -5.82509128]
#  [ 2.6710218  -5.09414739]
#  [ 2.96865734 -5.90100476]
#  [ 2.80743078 -5.42973458]
#  [ 6.79613769 -6.00016292]
#  [ 6.44375385 -5.63392182]
#  [ 6.97540442 -5.81891356]
#  [ 5.6923103  -4.48911979]
#  [ 6.59847758 -5.39011412]
#  [ 6.15177985 -4.89740025]
#  [ 6.60656681 -5.59861494]
#  [ 4.75987596 -4.31361622]
#  [ 6.55464088 -5.54368064]
#  [ 5.50115303 -4.59414886]
#  [ 5.0002569  -4.05223178]
#  [ 6.02244116 -5.21243963]
#  [ 5.77367885 -4.76683043]
#  [ 6.49538764 -5.19036331]
#  [ 5.3364791  -5.06290816]
#  [ 6.43891604 -5.78295994]
#  [ 6.17093589 -4.96274744]
#  [ 5.74588368 -4.9828019 ]
#  [ 6.45370481 -4.77290147]
#  [ 5.5545895  -4.73323428]
#  [ 6.62758382 -5.23050972]
#  [ 5.86812967 -5.2478999 ]
#  [ 6.80781195 -4.98716221]
#  [ 6.43184575 -5.13233337]
#  [ 6.22535131 -5.46510288]
#  [ 6.41098396 -5.64433471]
#  [ 6.84238452 -5.55939325]
#  [ 7.06873937 -5.58211632]
#  [ 6.32379865 -5.15239216]
#  [ 5.20400834 -4.94963712]
#  [ 5.44100021 -4.6121858 ]
#  [ 5.31945861 -4.63723319]
#  [ 5.64633805 -5.00301409]
#  [ 6.89008008 -4.89351859]
#  [ 6.09861795 -4.83143946]
#  [ 6.31854859 -5.50977769]
#  [ 6.73177206 -5.72275907]
#  [ 6.32421089 -4.94404473]
#  [ 5.75653826 -5.0479957 ]
#  [ 5.67585653 -4.63506226]
#  [ 5.97437409 -4.64519718]
#  [ 6.40150354 -5.28091129]
#  [ 5.74022215 -4.91246611]
#  [ 4.80426181 -4.30629897]
#  [ 5.86687614 -4.81150524]
#  [ 5.84247005 -5.10354359]
#  [ 5.88658133 -5.02310171]
#  [ 6.15303338 -5.33379491]
#  [ 4.60287976 -4.56315501]
#  [ 5.80915101 -4.96770721]
#  [ 8.04307008 -5.30288149]
#  [ 6.92541532 -4.73979867]
#  [ 8.12782771 -5.65665902]
#  [ 7.48215804 -5.13359804]
#  [ 7.86110108 -5.27284118]
#  [ 8.90822302 -5.86189178]
#  [ 6.03072634 -4.12337204]
#  [ 8.44334819 -5.66710074]
#  [ 7.83101589 -5.06917556]
#  [ 8.42947733 -6.09510436]
#  [ 7.17327804 -5.55676213]
#  [ 7.31368355 -5.09856912]
#  [ 7.67672196 -5.53000401]
#  [ 6.85593732 -4.53830831]
#  [ 7.0966104  -4.77541668]
#  [ 7.41608668 -5.43354272]
#  [ 7.46059188 -5.35545399]
#  [ 9.00010848 -6.48626828]
#  [ 9.30602996 -5.5679893 ]
#  [ 6.80967292 -4.55370979]
#  [ 7.93951036 -5.6915057 ]
#  [ 6.70944047 -4.70914477]
#  [ 9.01060858 -5.7714972 ]
#  [ 6.89901135 -5.11069274]
#  [ 7.78719675 -5.64811026]
#  [ 8.12553693 -5.87309068]
#  [ 6.76896828 -5.13558673]
#  [ 6.80201275 -5.19829848]
#  [ 7.63419708 -5.10386885]
#  [ 7.8989075  -5.77724298]
#  [ 8.35230402 -5.68746632]
#  [ 8.743686   -6.68524777]
#  [ 7.67008147 -5.0963982 ]
#  [ 6.9544457  -5.17092244]
#  [ 7.2909832  -4.81325894]
#  [ 8.58786472 -6.00048817]
#  [ 7.65632995 -5.45363034]
#  [ 7.41620602 -5.36277124]
#  [ 6.68019657 -5.15022123]
#  [ 7.61899683 -5.68620598]
#  [ 7.82564649 -5.49733258]
#  [ 7.43379398 -5.72399491]
#  [ 6.92541532 -4.73979867]
#  [ 8.07466581 -5.59069823]
#  [ 7.93073432 -5.61822767]
#  [ 7.45536015 -5.50213895]
#  [ 7.03700673 -4.93970288]
#  [ 7.27538903 -5.39324292]
#  [ 7.41297217 -5.43060048]
#  [ 6.90100923 -5.03183702]]

# %% [markdown]
# > 预期输出

# %% [markdown]
# ![](https://ai-studio-static-online.cdn.bcebos.com/3f615623531a4a94ad2552946e896d2dc1cec92685554f49bebfdf987d87ee54)

# %% [markdown]
# ## 任务2：sklearn中的PCA

# %% [markdown]
# ### 任务介绍
# - 请使用sklearn中的decomposition.pca将鸢尾花数据iris映射到二维低维空间，其中X是去除标签的数据，y是标签数据
# - 请计算第一主成分的方差占比，并存为变量fpc（用于判定本题是否通过）
# - 请尝试绘制低维空间中不同类别数据的散点图，并分析使用其中一个主成分是否可以准确分辨不同类别？

# %% [markdown]
# > 待补全代码

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# 加载数据
iris = pd.read_csv('iris.csv', usecols=range(5))
X=iris.iloc[:,1:4]
y = iris['classes']

# pca降维过程
pca = PCA(n_components=2)
pca.fit(X)
## 参考https://blog.csdn.net/weixin_44376037/article/details/122245411
X_pca = pca.transform(X)
# 计算第一主成分方差占比
fpc = pca.explained_variance_ratio_[0]

# 在低维空间中绘图
colors = ['green','c','orange'] # 色系选择
f,ax = plt.subplots(figsize=(6,6))
for color, label in zip(colors, y.unique()):
    plt.scatter(X_pca[y == label, 0], 
                X_pca[y == label, 1],
                color=color, 
                lw=2, 
                label=label)
plt.legend(loc="upper center")
plt.title("PCA of iris dataset")

# 请直接运行处结果，然后提交作业，该运行结果会自动一同提交上去
# Out:
# Text(0.5,1,'PCA of iris dataset')

# %% [markdown]
# > 预期输出

# %% [markdown]
# ![](https://ai-studio-static-online.cdn.bcebos.com/662dac8a81e64cd9b38b0def57707118270675c4e22f46aa9cc8e89bc88b255f)

# %% [markdown]
# ## 任务3：距离计算

# %% [markdown]
# ### 任务介绍
# - 构建自定义函数cal_eculidean(array_a, array_b)函数，计算欧式距离。输入变量为ndarray类型数组，返回结果为二者之间的欧式距离；
# - 针对测试集test_data中的每个数据样本，使用自定义函数计算其和训练集每个样本的欧式距离，保存在变量distances中。

# %% [markdown]
# > 待补全代码

# %%
import pandas as pd
import numpy as np
train_data = pd.read_table('gender.csv', sep = ',')
test_data = pd.read_table('test.csv', sep = ',')

# 请在下方作答 #

def cal_eculidean(array_a, array_b):
    
    ## 计算两个变量各个维度的差的平方
    array_square = np.power(array_a-array_b, 2)
    
    ## 计算差的平方和array_square_sum
    array_square_sum = array_square.sum()
    
    ## 开根号
    sum_root = np.sqrt(array_square_sum)
    
    return sum_root

## 储存距离的变量
distances = []

## 遍历`test_data`中的每个数据样本, 样本的储存格式为ndarray
for item in test_data.iloc[:,:-1].values:
    
    ## 储存数据样本和训练集中每个样本的距离，dist格式为字典类型，形如{index: distance}
    dist = {}
    
    for index, train_item in enumerate(train_data.iloc[:,:-1].values):
        
        ## 使用自定义函数计算item和train_item之间的欧式距离distance
        distance = cal_eculidean(item, train_item)
        ## 将distance和train_item的index存入字典变量dist中
        dist[index] = distance
    
    #将dist加入到distances中
    distances.append(dist)

print(distances)
# Out:
# [{0: 32.449961479175904, 1: 27.294688127912362, 2: 19.697715603592208, 3: 29.206163733020468, 4: 35.608987629529715, 5: 27.459060435491963, 6: 22.20360331117452, 7: 23.430749027719962, 8: 31.064449134018133, 9: 31.622776601683793, 10: 31.622776601683793, 11: 30.805843601498726, 12: 26.570660511172846, 13: 31.622776601683793, 14: 26.419689627245813, 15: 22.20360331117452, 16: 10.295630140987, 17: 18.973665961010276, 18: 29.206163733020468, 19: 29.206163733020468, 20: 26.92582403567252, 21: 33.28663395418648, 22: 26.40075756488817, 23: 28.319604517012593, 24: 21.633307652783937, 25: 34.0, 26: 26.90724809414742, 27: 29.154759474226502, 28: 30.4138126514911, 29: 33.12099032335839, 30: 33.97057550292606, 31: 19.6468827043885, 32: 22.360679774997898, 33: 21.93171219946131, 34: 33.97057550292606, 35: 40.22437072223753, 36: 30.886890422961002, 37: 39.408120990476064, 38: 21.095023109728988, 39: 22.80350850198276, 40: 32.7566787083184, 41: 22.20360331117452, 42: 32.55764119219941, 43: 27.459060435491963, 44: 28.635642126552707, 45: 18.867962264113206, 46: 29.206163733020468, 47: 29.58462438497403, 48: 31.144823004794873, 49: 26.627053911388696, 50: 11.0, 51: 7.810249675906654, 52: 27.892651361962706, 53: 15.264337522473747, 54: 5.830951894845301, 55: 11.0, 56: 10.295630140987, 57: 10.920164833920778, 58: 19.697715603592208, 59: 23.40939982143925, 60: 24.351591323771842, 61: 17.0, 62: 5.385164807134504, 63: 7.0, 64: 9.848857801796104, 65: 13.341664064126334, 66: 4.242640687119285, 67: 10.0, 68: 9.486832980505138, 69: 9.486832980505138, 70: 6.4031242374328485, 71: 17.4928556845359, 72: 13.92838827718412, 73: 13.601470508735444, 74: 5.0, 75: 12.0, 76: 8.54400374531753, 77: 9.433981132056603, 78: 23.259406699226016, 79: 10.770329614269007, 80: 8.54400374531753, 81: 9.486832980505138, 82: 7.211102550927978, 83: 4.242640687119285, 84: 5.830951894845301, 85: 7.280109889280518, 86: 19.209372712298546, 87: 13.92838827718412, 88: 6.4031242374328485, 89: 8.94427190999916, 90: 11.180339887498949, 91: 8.246211251235321, 92: 17.0, 93: 11.313708498984761, 94: 13.0, 95: 10.198039027185569, 96: 4.242640687119285, 97: 10.63014581273465, 98: 8.54400374531753, 99: 11.313708498984761, 100: 12.206555615733702, 101: 5.830951894845301, 102: 7.615773105863909, 103: 8.246211251235321, 104: 6.708203932499369, 105: 7.280109889280518, 106: 7.810249675906654, 107: 10.63014581273465, 108: 6.708203932499369, 109: 11.704699910719626, 110: 11.661903789690601, 111: 22.0, 112: 9.433981132056603, 113: 17.029386365926403, 114: 25.079872407968907, 115: 8.06225774829855, 116: 11.313708498984761, 117: 10.44030650891055, 118: 2.0, 119: 15.297058540778355, 120: 13.038404810405298, 121: 2.8284271247461903, 122: 5.385164807134504, 123: 8.246211251235321, 124: 17.08800749063506, 125: 13.341664064126334, 126: 18.384776310850235, 127: 7.0, 128: 10.594810050208546, 129: 21.18962010041709, 130: 11.661903789690601, 131: 20.615528128088304, 132: 23.853720883753127, 133: 7.0, 134: 13.038404810405298, 135: 19.697715603592208, 136: 4.47213595499958, 137: 11.0, 138: 10.770329614269007, 139: 10.63014581273465, 140: 27.073972741361768, 141: 2.5, 142: 9.433981132056603, 143: 0.0, 144: 18.681541692269406, 145: 2.8284271247461903, 146: 11.40175425099138, 147: 4.0, 148: 10.816653826391969, 149: 7.280109889280518, 150: 3.605551275463989, 151: 12.041594578792296, 152: 15.264337522473747, 153: 2.23606797749979, 154: 10.295630140987, 155: 2.8284271247461903, 156: 10.63014581273465, 157: 2.0, 158: 13.416407864998739, 159: 12.165525060596439, 160: 17.0, 161: 25.495097567963924, 162: 4.47213595499958, 163: 15.264337522473747, 164: 8.602325267042627, 165: 9.433981132056603, 166: 18.110770276274835, 167: 9.433981132056603, 168: 7.0, 169: 8.0, 170: 13.45362404707371, 171: 8.602325267042627, 172: 15.264337522473747, 173: 13.92838827718412, 174: 13.92838827718412, 175: 5.830951894845301, 176: 13.341664064126334, 177: 4.242640687119285, 178: 6.324555320336759, 179: 8.54400374531753, 180: 0.0, 181: 16.97056274 ...

# %% [markdown]
# > 预期输出

# %% [markdown]
# ![](https://ai-studio-static-online.cdn.bcebos.com/eda44e812f6447028e194790d4046d78c93bbbddd2084d069daa783f9c4195ec)

# %% [markdown]
# ## 任务4：选择最近邻样本

# %% [markdown]
# ### 任务介绍
# - 对于distances中的每个字典元素的值进行递增排序，选择距离最小的K个样本，将样本的索引保存在变量index_list中。

# %% [markdown]
# > 待补全代码

# %%
# item = distances[0]
# sorted_item = sorted(item.items(), key = lambda x: x[1])[:11]  # 每个item都是一个字典
# list(zip(*sorted_item))[0]
# list(zip(*sorted_item))

# %%
## 声明储存K个邻居的index的列表
index_list = []
K = 11
## 遍历每个测试样本的与训练集的举例，item类型为dict
for item in distances:

    ## item的类型为dict，即{'index': distance}
    ## 使用sorted函数对item按照diatance进行升序排列,并取前K个距离最小的样本
    ## sorted_item形如[(index, distance),(index, distance)...(index, distance)]
    ## 参考https://blog.csdn.net/weixin_43603464/article/details/107198968
    # sorted_item = sorted(item, key=lambda x: item[x])[:K]  # 每个item都是一个字典
    ## 参考http://t.zoukankan.com/xueqiuxiang-p-14466960.html
    sorted_item = sorted(item.items(), key = lambda x: x[1])[:K]  # 这样排序得到的是元组, 上面那样排序得到的直接就是list了

    ## 使用zip函数从sorted_items中获取对应的index
    indexes = list(zip(*sorted_item))[0]
    
    ## 将获取的indexes加入到index_list中
    index_list.append(indexes)

index_list
# Out:
# [(143, 180, 182, 284, 118, 157, 153, 194, 242, 141, 121),
#  (181, 160, 207, 212, 154, 252, 164, 128, 159, 186, 88),
#  (182, 118, 143, 157, 180, 284, 141, 155, 153, 194, 242),
#  (183, 170, 239, 73, 151, 270, 93, 99, 116, 199, 258),
#  (110, 130, 184, 247, 299, 16, 56, 146, 158, 198, 64),
#  (185, 178, 257, 70, 105, 122, 249, 103, 195, 250, 167),
#  (186, 91, 255, 88, 187, 252, 154, 133, 269, 220, 164),
#  (187, 91, 255, 133, 220, 186, 237, 269, 252, 154, 88),
#  (188, 152, 163, 172, 241, 71, 61, 73, 92, 270, 288),
#  (189, 256, 75, 111, 228, 159, 50, 215, 260, 128, 160),
#  (190, 147, 211, 224, 74, 150, 202, 274, 121, 136, 145),
#  (191, 296, 262, 65, 125, 134, 176, 222, 226, 287, 297),
#  (192, 232, 101, 298, 51, 106, 108, 62, 115, 219, 261),
#  (94, 193, 267, 120, 134, 262, 55, 137, 286, 296, 90),
#  (153, 194, 242, 121, 150, 66, 83, 96, 143, 180, 224),
#  (103, 195, 105, 169, 178, 209, 248, 250, 275, 283, 127),
#  (179, 196, 205, 68, 81, 89, 102, 123, 201, 243, 244),
#  (197, 272, 286, 119, 120, 138, 94, 193, 267, 278, 55),
#  (198, 77, 97, 107, 112, 142, 165, 238, 246, 16, 56),
#  (93, 99, 116, 199, 258, 97, 107, 151, 146, 198, 100),
#  (29, 25, 40, 21, 36, 0, 28, 8, 9, 10, 13),
#  (30, 34, 42, 48, 4, 11, 9, 10, 13, 0, 3),
#  (31, 144, 245, 268, 210, 277, 129, 216, 235, 131, 2),
#  (32, 200, 78, 240, 38, 131, 2, 24, 58, 59, 135),
#  (33, 273, 7, 254, 39, 236, 86, 24, 126, 6, 15),
#  (30, 34, 42, 48, 4, 11, 9, 10, 13, 0, 3),
#  (35, 37, 4, 21, 25, 0, 40, 30, 34, 29, 9),
#  (36, 28, 47, 27, 8, 29, 40, 0, 9, 10, 13),
#  (37, 35, 4, 21, 30, 34, 0, 40, 25, 29, 9),
#  (38, 24, 276, 236, 32, 45, 200, 266, 132, 2, 39),
#  (39, 7, 236, 254, 24, 33, 132, 273, 38, 263, 22),
#  (40, 21, 0, 29, 8, 9, 10, 13, 25, 36, 11),
#  (6, 15, 41, 273, 33, 14, 126, 113, 7, 254, 86),
#  (42, 30, 34, 48, 4, 3, 11, 19, 46, 9, 10),
#  (5, 43, 49, 253, 27, 263, 1, 22, 47, 3, 19)]

# %% [markdown]
# > 预期输出
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/ebe719d982d5428ea34d4d1a4cd512b406de27d7a8b84bc2aacc483d07044d92)

# %% [markdown]
# ## 任务5：确定样本预测类别

# %% [markdown]
# ### 任务介绍
# - 按照index_list，对train_data进行切片，获取测试数据集中每个样本的K个邻居的数据记录neighbor_df；
# - 针对每个测试样本，查看neighbor_df的特征gender的取值，获取出现频率最高的值，存入到数组pred_label中；
# - 根据pred_label和test_data的特征gender取值，计算K近邻算法的正确率accuracy_rate。

# %% [markdown]
# > 待补全代码

# %%
# indexes = index_list[-1]
# train_data.iloc[list(indexes)]['gender'].value_counts().index[0]
# test_data
# np.array(test_data['gender']) - np.array([1 for i in range(len(test_data))])

# %%
## 声明预测类别数组
pred_label = []

## 遍历索引数组
for indexes in index_list:
    
    ## 获取测试样本K个邻居的数据记录neighbor_df,类型为Dataframe
    #### 参考https://blog.csdn.net/u013250861/article/details/124065734
    neighbor_df = train_data.iloc[list(indexes)]  # 按下标多行索引, 必须用list不能用元组, 吐了, 试了半天
    
    ## 找到出现频率最高的类别mode_value，类型为str
    mode_value = neighbor_df['gender'].value_counts().index[0]
    
    ## 将mode_value保存在pred_label
    pred_label.append(mode_value)
    
## 将取值作变换 ‘M’:1  ‘F’:0
pred_label = [1 if item == 'M' else 0 for item in pred_label]

## 预测值与真实值相减，获得结果diff
diff = np.array(test_data['gender']) - np.array(pred_label)

## 计算正确率
accuracy_rate = (len(test_data) - np.abs(diff).sum()) / len(test_data)
print(accuracy_rate)
# Out:
# 0.9428571428571428

# %% [markdown]
# > 预期输出
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/ec61aae5ceec4df98f7fa0a3423e47ef7df109d8d9d044f1b315fec95f545ab7)

# %% [markdown]
# ## 任务6：K值的选择

# %% [markdown]
# ### 任务介绍
# - 根据任务3-任务5的代码，编写自定义函数knn_classify(train_data, test_data, k)；
# - 在训练集train_data和测试集test_data上运行K近邻算法；
# - 算法K的取值范围为[3, 20]，针对每个K，计算预测错误样本的个数error_num；
# - 绘制折线图， x轴为K的取值范围，y轴为正确率。

# %% [markdown]
# > 待补全代码

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
train_data = pd.read_table('gender.csv', sep = ',')
test_data = pd.read_table('test.csv', sep = ',')

# 自定义函数 knn_classify(train_data, test_data, k)；
def knn_classify(train_data, test_data, k):
    # 距离变量
    # 请在下方补充
    def cal_eculidean(array_a, array_b):
        ## 计算两个变量各个维度的差的平方
        array_square = np.power(array_a-array_b, 2)
        ## 计算差的平方和array_square_sum
        array_square_sum = array_square.sum()
        ## 开根号
        sum_root = np.sqrt(array_square_sum)
        return sum_root

    ## 储存距离的变量
    distances = []
    ## 遍历`test_data`中的每个数据样本, 样本的储存格式为ndarray
    for item in test_data.iloc[:,:-1].values: 
        ## 储存数据样本和训练集中每个样本的距离，dist格式为字典类型，形如{index: distance}
        dist = {}
        for index, train_item in enumerate(train_data.iloc[:,:-1].values):
            ## 使用自定义函数计算item和train_item之间的欧式距离distance
            distance = cal_eculidean(item, train_item)
            ## 将distance和train_item的index存入字典变量dist中
            dist[index] = distance
        #将dist加入到distances中
        distances.append(dist)

    # 获取K个样本的索引
    # 请在下方补充
    ## 声明储存K个邻居的index的列表
    index_list = []
    ## 遍历每个测试样本的与训练集的举例，item类型为dict
    for item in distances:
        ## item的类型为dict，即{'index': distance}
        ## 使用sorted函数对item按照diatance进行升序排列,并取前K个距离最小的样本
        ## sorted_item形如[(index, distance),(index, distance)...(index, distance)]
        ## 参考https://blog.csdn.net/weixin_43603464/article/details/107198968
        # sorted_item = sorted(item, key=lambda x: item[x])[:K]  # 每个item都是一个字典
        ## 参考http://t.zoukankan.com/xueqiuxiang-p-14466960.html
        sorted_item = sorted(item.items(), key = lambda x: x[1])[:k]  # 这样排序得到的是元组, 上面那样排序得到的直接就是list了
        ## 使用zip函数从sorted_items中获取对应的index
        indexes = list(zip(*sorted_item))[0]
        ## 将获取的indexes加入到index_list中
        index_list.append(indexes)

    # 确定样本预测类别
    # 请在下方补充
    ## 声明预测类别数组
    pred_label = []
    ## 遍历索引数组
    for indexes in index_list:
        ## 获取测试样本K个邻居的数据记录neighbor_df,类型为Dataframe
        #### 参考https://blog.csdn.net/u013250861/article/details/124065734
        neighbor_df = train_data.iloc[list(indexes)]  # 按下标多行索引, 必须用list不能用元组, 吐了, 试了半天 
        ## 找到出现频率最高的类别mode_value，类型为str
        mode_value = neighbor_df['gender'].value_counts().index[0]
        ## 将mode_value保存在pred_label
        pred_label.append(mode_value)

    return pred_label

## 声明保存预测错误样本个数列表
error = []

## K的取值范围
k_value = range(3, 20, 1)

## 遍历K = 3，4，5，6 ... 20
for num in k_value:
    
    ## 调用knn_classify函数，返回预测结果pred
    pred = knn_classify(train_data, test_data, num)
    
    ## 预测结果转换 ‘M’:1 'F':0
    pred = [1 if item == 'M' else 0 for item in pred]

    ## 预测值与真实值之差
    diff = np.array(test_data['gender']) - np.array(pred)

    ## 统计预测错误的样本个数
    error_num = np.abs(diff).sum()
    ## 将具体的K值对应的样本个数保存到列表error
    error.append(error_num)
    

## 计算正确率
rate_list = (len(test_data) - np.array(error)) / len(test_data)

print(rate_list)
## 绘制折线图
plt.plot(k_value, rate_list,  '--r*')
## 输出图像
plt.show()
# Out:
# [0.94285714 0.85714286 0.94285714 0.91428571 0.91428571 0.85714286
#  0.88571429 0.85714286 0.94285714 0.88571429 0.91428571 0.88571429
#  0.91428571 0.91428571 0.91428571 0.91428571 0.91428571]

# %% [markdown]
# > 预期输出
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/3bcc83b6e2654194a1241d82eaee3d08bfe1a09348514e688ee87d01d49e55b2)
